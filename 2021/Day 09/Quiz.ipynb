# %% [markdown]
# # --- Day 9: Smoke Basin ---

# %%
from Quiz import *
from numpy import prod

# %% [markdown]
# ### --- Part One ---

# %% [markdown]
# These caves seem to be lava tubes https://en.wikipedia.org/wiki/Lava_tube . Parts are even still volcanically active; small hydrothermal vents release smoke into the caves that slowly <ins>settles like rain</ins>.
#
# If you can model how the smoke flows through the caves, you might be able to avoid it and be that much safer. The submarine generates a heightmap of the floor of the nearby caves for you (your puzzle input).
#
# Smoke flows to the lowest point of the area it's in. For example, consider the following heightmap:
#
# `2`__`1`__`9994321`__`0`__ <br>
# `3987894921` <br>
# `98`__`5`__`6789892` <br>
# `8767896789` <br>
# `989996`__`5`__`678`
#
# Each number corresponds to the height of a particular location, where `9` is the highest and `0` is the lowest a location can be.
#
# Your first goal is to find the __low points__ - the locations that are lower than any of its adjacent locations. Most locations have four adjacent locations (up, down, left, and right); locations on the edge or corner of the map have three or two adjacent locations, respectively. (Diagonal locations do not count as adjacent.)
#
# In the above example, there are __four__ low points, all highlighted: two are in the first row (a `1` and a `0`), one is in the third row (a `5`), and one is in the bottom row (also a `5`). All other locations on the heightmap have some lower adjacent location, and so are not low points.
#
# The __risk level__ of a low point is __1 plus its height__. In the above example, the risk levels of the low points are `2`, `1`, `6`, and `6`. The sum of the risk levels of all low points in the heightmap is therefore __`15`__.
#
# Find all of the low points on your heightmap.
#
# __What is the sum of the risk levels of all low points on your heightmap__?

# %% [markdown]
# #### Test

# %%
low_points = []

for l in range(len(test_heightmap_1)):
    
    for c in range(len(test_heightmap_1[l])):
        
        if (l == 0):
            
            if (c == 0):
                
                down = test_heightmap_1[l][c] < test_heightmap_1[l + 1][c]
                right = test_heightmap_1[l][c] < test_heightmap_1[l][c + 1]
                
                if (down and right):

                    low_points.append(test_heightmap_1[l][c])
            
            elif (c == len(test_heightmap_1[l]) - 1):
                
                down = test_heightmap_1[l][c] < test_heightmap_1[l + 1][c]
                left = test_heightmap_1[l][c] < test_heightmap_1[l][c - 1]
                
                if (down and left):

                    low_points.append(test_heightmap_1[l][c])
                    
            else:
                
                down = test_heightmap_1[l][c] < test_heightmap_1[l + 1][c]
                left = test_heightmap_1[l][c] < test_heightmap_1[l][c - 1]
                right = test_heightmap_1[l][c] < test_heightmap_1[l][c + 1]
                
                if (down and left and right):

                    low_points.append(test_heightmap_1[l][c])
                    
        elif (l == len(test_heightmap_1) - 1):
             
            if (c == 0):
                
                up = test_heightmap_1[l][c] < test_heightmap_1[l - 1][c]
                right = test_heightmap_1[l][c] < test_heightmap_1[l][c + 1]
                
                if (right and up):

                    low_points.append(test_heightmap_1[l][c])
            
            elif (c == len(test_heightmap_1[l]) - 1):
                
                up = test_heightmap_1[l][c] < test_heightmap_1[l - 1][c]
                left = test_heightmap_1[l][c] < test_heightmap_1[l][c - 1]
                
                if (left and up):

                    low_points.append(test_heightmap_1[l][c])
                    
            else:
                
                up = test_heightmap_1[l][c] < test_heightmap_1[l - 1][c]
                left = test_heightmap_1[l][c] < test_heightmap_1[l][c - 1]
                right = test_heightmap_1[l][c] < test_heightmap_1[l][c + 1]
                
                if (left and right and up):

                    low_points.append(test_heightmap_1[l][c])
        else:
            
            if (c == 0):
                
                up = test_heightmap_1[l][c] < test_heightmap_1[l - 1][c]
                down = test_heightmap_1[l][c] < test_heightmap_1[l + 1][c]
                right = test_heightmap_1[l][c] < test_heightmap_1[l][c + 1]
                
                if (down and right and up):

                    low_points.append(test_heightmap_1[l][c])
            
            elif (c == len(test_heightmap_1[l]) - 1):
                
                up = test_heightmap_1[l][c] < test_heightmap_1[l - 1][c]
                down = test_heightmap_1[l][c] < test_heightmap_1[l + 1][c]
                left = test_heightmap_1[l][c] < test_heightmap_1[l][c - 1]
                
                if (down and left and up):

                    low_points.append(test_heightmap_1[l][c])
                    
            else:
                
                up = test_heightmap_1[l][c] < test_heightmap_1[l - 1][c]
                down = test_heightmap_1[l][c] < test_heightmap_1[l + 1][c]
                left = test_heightmap_1[l][c] < test_heightmap_1[l][c - 1]
                right = test_heightmap_1[l][c] < test_heightmap_1[l][c + 1]
                
                if (down and left and right and up):
                    
                    low_points.append(test_heightmap_1[l][c])
                    

risk = [int(l) + 1 for l in low_points]

print("Sum of risk levels:" , sum(risk))
# Out:
# Sum of risk levels: 15

# %% [markdown]
# #### Answer

# %%
low_points = []

for l in range(len(heightmap)):
    
    for c in range(len(heightmap[l])):
        
        if (l == 0):
            
            if (c == 0):
                
                down = heightmap[l][c] < heightmap[l + 1][c]
                right = heightmap[l][c] < heightmap[l][c + 1]
                
                if (down and right):

                    low_points.append(heightmap[l][c])
            
            elif (c == len(heightmap[l]) - 1):
                
                down = heightmap[l][c] < heightmap[l + 1][c]
                left = heightmap[l][c] < heightmap[l][c - 1]
                
                if (down and left):

                    low_points.append(heightmap[l][c])
                    
            else:
                
                down = heightmap[l][c] < heightmap[l + 1][c]
                left = heightmap[l][c] < heightmap[l][c - 1]
                right = heightmap[l][c] < heightmap[l][c + 1]
                
                if (down and left and right):

                    low_points.append(heightmap[l][c])
                    
        elif (l == len(heightmap) - 1):
             
            if (c == 0):
                
                up = heightmap[l][c] < heightmap[l - 1][c]
                right = heightmap[l][c] < heightmap[l][c + 1]
                
                if (right and up):

                    low_points.append(heightmap[l][c])
            
            elif (c == len(heightmap[l]) - 1):
                
                up = heightmap[l][c] < heightmap[l - 1][c]
                left = heightmap[l][c] < heightmap[l][c - 1]
                
                if (left and up):

                    low_points.append(heightmap[l][c])
                    
            else:
                
                up = heightmap[l][c] < heightmap[l - 1][c]
                left = heightmap[l][c] < heightmap[l][c - 1]
                right = heightmap[l][c] < heightmap[l][c + 1]
                
                if (left and right and up):

                    low_points.append(heightmap[l][c])
        else:
            
            if (c == 0):
                
                up = heightmap[l][c] < heightmap[l - 1][c]
                down = heightmap[l][c] < heightmap[l + 1][c]
                right = heightmap[l][c] < heightmap[l][c + 1]
                
                if (down and right and up):

                    low_points.append(heightmap[l][c])
            
            elif (c == len(heightmap[l]) - 1):
                
                up = heightmap[l][c] < heightmap[l - 1][c]
                down = heightmap[l][c] < heightmap[l + 1][c]
                left = heightmap[l][c] < heightmap[l][c - 1]
                
                if (down and left and up):

                    low_points.append(heightmap[l][c])
                    
            else:
                
                up = heightmap[l][c] < heightmap[l - 1][c]
                down = heightmap[l][c] < heightmap[l + 1][c]
                left = heightmap[l][c] < heightmap[l][c - 1]
                right = heightmap[l][c] < heightmap[l][c + 1]
                
                if (down and left and right and up):
                    
                    low_points.append(heightmap[l][c])
                    

risk = [int(l) + 1 for l in low_points]

print("Sum of risk levels:" , sum(risk))
# Out:
# Sum of risk levels: 585

# %% [markdown]
# -------------------------------------

# %% [markdown]
# ### --- Part Two ---

# %% [markdown]
# Next, you need to find the largest basins so you know what areas are most important to avoid.
#
# A __basin__ is all locations that eventually flow downward to a single low point. Therefore, every low point has a basin, although some basins are very small. Locations of height 9 do not count as being in any basin, and all other locations will always be part of exactly one basin.
#
# The __size__ of a basin is the number of locations within the basin, including the low point. The example above has four basins.
#
# The top-left basin, size `3`:
#
# __`21`__`99943210` <br>
# __`3`__`987894921` <br>
# `9856789892` <br>
# `8767896789` <br>
# `9899965678`
#
# The top-right basin, size `9`:
#
# `21999`__`43210`__ <br>
# `398789`__`4`__`9`__`21`__ <br>
# `985678989`__`2`__ <br>
# `8767896789` <br>
# `9899965678`
#
# The middle basin, size `14`:
#
# `2199943210` <br>
# `39`__`878`__`94921` <br>
# `9`__`85678`__`9892` <br>
# __`87678`__`96789` <br>
# `9`__`8`__`99965678`
#
# The bottom-right basin, size `9`:
#
# `2199943210` <br>
# `3987894921` <br>
# `9856789`__`8`__`92` <br>
# `876789`__`678`__`9` <br>
# `98999`__`65678`__
#
# Find the three largest basins and multiply their sizes together. In the above example, this is `9 * 14 * 9 = 1134`.
#
# __What do you get if you multiply together the sizes of the three largest basins__?

# %%
#devolve o low_point ao qual a basin pertence
def basin(l , c , h_map):
    
    downhill = None
    
    for (d_l, d_c) in [(l - 1 , c), (l + 1 , c), (l , c - 1), (l , c + 1)]:
        
        if ((d_l in range(len(h_map))) and (d_c in range(len(h_map[0])))):
            
            if (h_map[l][c] > h_map[d_l][d_c]):
                
                downhill = (d_l , d_c)
                
    if (downhill == None):
        
        return (l , c)
    
    ret = basin(downhill[0] , downhill[1] , h_map)
    return ret

# %% [markdown]
# #### Test

# %%
basins = []

for l in range(len(test_heightmap_1)):
    
    for c in range(len(test_heightmap_1[l])):
        
        if test_heightmap_1[l][c] != 9:

            basins.append(basin(l , c , test_heightmap_1))

basin_counter = {}
for b in basins:
    
    if (basin_counter.get(b) == None):
        
        basin_counter[b] = 1
    
    else:
        
        basin_counter[b] = basin_counter.get(b) + 1
        
        
biggest = [c for c in basin_counter.values()]
biggest.sort()
biggest = biggest[-3:]
size = prod(biggest)
    
print("Three Largest Basins:" , size)
# Out:
# Three Largest Basins: 1134

# %% [markdown]
# #### Answer

# %%
basins = []

for l in range(len(heightmap)):
    
    for c in range(len(heightmap[l])):
        
        if heightmap[l][c] != 9:

            basins.append(basin(l , c , heightmap))

basin_counter = {}
for b in basins:
    
    if (basin_counter.get(b) == None):
        
        basin_counter[b] = 1
    
    else:
        
        basin_counter[b] = basin_counter.get(b) + 1
        
        
biggest = [c for c in basin_counter.values()]
biggest.sort()
biggest = biggest[-3:]
size = prod(biggest)
    
print("Three Largest Basins:" , size)
# Out:
# Three Largest Basins: 827904
